# %%
import pandas as pd
from datetime import date
import random

# %%
verbs = pd.read_excel("verbs.xlsx")
df = pd.read_excel("VerbBender.xlsx")

# %%
verbs = verbs[verbs.A2 == "Y"].reset_index()

# %%
verbs
# Out:
#     index          English    Infinitive Present tense    Past tense  \
# 0       2           employ     å ansette      ansetter       ansatte
# 1       5        interrupt     å avbryte      avbryter        avbrøt
# 2       9      bear, carry        å bære         bærer           bar
# 3      12              ask          å be           ber            ba
# 4      30               be         å bli          blir    ble / blei
# 5      39   violate, break       å bryte        bryter   brøt, brøyt
# 6      52            drink      å drikke       drikker         drakk
# 7      53     operate, run       å drive        driver  drev / dreiv
# 8      62      get/receive          å få           får          fikk
# 9      65             find       å finne        finner          fant
# 10     77           prefer  å foretrekke   foretrekker     foretrakk
# 11     82       understand      å forstå       forstår        forsto
# 12     83        disappear   å forsvinne    forsvinner      forsvant
# 13     84    tell, explain    å fortelle     forteller      fortalte
# 14     85         continue   å fortsette    fortsetter     fortsatte
# 15     89         go, walk          å gå           går          gikk
# 16     92             give          å gi           gir           gav
# 17     95           repeat      å gjenta       gjentar       gjentok
# 18     97               do       å gjøre          gjør        gjorde
# 19    107             have          å ha           har         hadde
# 20    116             help      å hjelpe       hjelper         hjalp
# 21    145   can/be able to       å kunne           kan         kunne
# 22    151            laugh          å le           ler            lo
# 23    152          lay/put       å legge        legger            la
# 24    160              lie       å ligge        ligger            lå
# 25    182            enjoy        å nyte         nyter           nøt
# 26    188       exaggerate   å overdrive    overdriver      overdrev
# 27    210            reach       å rekke        rekker         rakte
# 28    216             ride          å ri           rir           red
# 29    229              see          å se           ser            så
# 30    230             sell       å selge        selger        solgte
# 31    233    set/put/place       å sette        setter         satte
# 32    234        say, tell          å si          sier            sa
# 33    236              sit       å sitte        sitter          satt
# 34    237              cut      å skjære       skjærer          skar
# 35    241            write      å skrive       skriver         skrev
# 36    243    should, shall      å skulle         skal         skulle
# 37    246      hit, strike         å slå          slår           slo
# 38    248             drop      å slippe       slipper         slapp
# 39    257            sneak       å snike        sniker          snek
# 40    269              ask      å spørre          spør        spurte
# 41    271  stand, stand up         å stå          står          stod
# 42    278            steal      å stjele       stjeler         stjal
# 43    282           stroke      å stryke       stryker         strøk
# 44    290             take          å ta           tar           tok
# 45    294            count       å telle        teller         talte
# 46    301         meet/hit      å treffe       treffer         traff
# 47    302             pull      å trekke       trekker         trakk
# 48    313        be, exist        å være            er           var
# 49    321    want to, will       å ville           vil         ville
# 50    325             know        å vite           vet        visste
#
#     Past participle A2
# 0        har ansatt  Y
# 1       har avbrutt  Y
# 2         har båret  Y
# 3          har bedt  Y
# 4         har blitt  Y
# 5         har brutt  Y
# 6       har drukket  Y
# 7        har drevet  Y
# 8          har fått  Y
# 9        har funnet  Y
# 10  har foretrukket  Y
# 11     har forstått  Y
# 12   har forsvunnet  Y
# 13      har fortalt  Y
# 14     har fortsatt  Y
# 15         har gått  Y
# 16         har gitt  Y
# 17         gjentatt  Y
# 18        har gjort  Y
# 19         har hatt  Y
# 20      har hjulpet  Y
# 21       har kunnet  Y
# 22         har ledd  Y
# 23         har lagt  Y
# 24       har ligget  Y
# 25         har nytt  Y
# 26       overdrevet  Y
# 27         har rakt  Y
# 28         har ridd  Y
# 29         har sett  Y
# 30        har solgt  Y
# 31         har satt  Y
# 32         har sagt  Y
# 33       har sittet  Y
# 34       har skåret  Y
# 35      har skrevet  Y
# 36      har skullet  Y
# 37        har slått  Y
# 38          sluppet  Y
# 39       har sneket  Y
# 40        har spurt  Y
# 41        har stått  Y
# 42      har stjålet  Y
# 43      har strøket  Y
# 44         har tatt  Y
# 45         har talt  Y
# 46      har truffet  Y
# 47      har trukket  Y
# 48         har vært  Y
# 49       har villet  Y
# 50        har visst  Y

# %%
def VerbBender():
    num = random.randrange(0, len(verbs))
    tenses = ['Infinitive','Present tense','Past tense','Past participle']
    print(verbs['English'][num])

    counter = 0
    atbilde = []
    atbilde.append(date.today().strftime("%d/%m/%Y"))
    atbilde.append(verbs['English'][num])
    for i in tenses:

        print(i)
        answer= input()
        atbilde.append(answer)

        if verbs[i][num] != answer:
            print(verbs[i][num])
            counter+= 1
    print("You got "+str((1 - counter/4)*100)+"% correct")
    atbilde.append((1 - counter/4)*100)
    df.loc[len(df)] = atbilde
    df.to_excel("VerbBender.xlsx", index = False)

# %%
VerbBender()
# Out:
# take
# Infinitive
# å ta
# Present tense
# tar
# Past tense
# tatt
# tok
# Past participle
# har tokte
# har tatt
# You got 50.0% correct

# %%
df.tail()
# Out:
#           Date      Verb Infinitive Present tense Past tense Past participle  \
# 54  07/01/2021     laugh       å la           ler        ler        har latt
# 55  07/01/2021  continue       å go     fortsette    forsatt     har forsatt
# 56  07/01/2021       ask   å sporre           ber         ba       har berte
# 57  07/01/2021    employ          [             p          p               p
# 58  07/01/2021      take       å ta           tar       tatt       har tokte
#
#     Percent
# 54     25.0
# 55      0.0
# 56     50.0
# 57      0.0
# 58     50.0
